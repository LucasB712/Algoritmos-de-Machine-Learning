# %% [markdown]
# # TRABALHO ML

# %%
import pandas as pd
df = pd.read_csv("https://raw.githubusercontent.com/bluenex/WekaLearningDataset/master/bank/bank-data.csv")
df.head()
# Out:
#         id  age     sex      region   income married  children  car save_act  \
# 0  ID12101   48  FEMALE  INNER_CITY  17546.0      NO         1   NO       NO
# 1  ID12102   40    MALE        TOWN  30085.1     YES         3  YES       NO
# 2  ID12103   51  FEMALE  INNER_CITY  16575.4     YES         0  YES      YES
# 3  ID12104   23  FEMALE        TOWN  20375.4     YES         3   NO       NO
# 4  ID12105   57  FEMALE       RURAL  50576.3     YES         0   NO      YES
#
#   current_act mortgage  pep
# 0          NO       NO  YES
# 1         YES      YES   NO
# 2         YES       NO   NO
# 3         YES       NO   NO
# 4          NO       NO   NO

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 600 entries, 0 to 599
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           600 non-null    object
#  1   age          600 non-null    int64
#  2   sex          600 non-null    object
#  3   region       600 non-null    object
#  4   income       600 non-null    float64
#  5   married      600 non-null    object
#  6   children     600 non-null    int64
#  7   car          600 non-null    object
#  8   save_act     600 non-null    object
#  9   current_act  600 non-null    object
#  10  mortgage     600 non-null    object
#  11  pep          600 non-null    object
# dtypes: float64(1), int64(2), object(9)
# memory usage: 56.4+ KB

# %% [markdown]
# # Tratamento dos dados

# %%
df.boxplot(figsize = (20,10), rot=90)
plt.show()

# %%
print(df['sex'].value_counts(normalize=True) * 100)
# Out:
# sex
# FEMALE    50.0
# MALE      50.0
# Name: proportion, dtype: float64

# %%
df['sex'] = df['sex'].replace("FEMALE",  0)
df['sex'] = df['sex'].replace("MALE",  1)

# %%
print(df['region'].value_counts(normalize=True) * 100)
# Out:
# region
# INNER_CITY    44.833333
# TOWN          28.833333
# RURAL         16.000000
# SUBURBAN      10.333333
# Name: proportion, dtype: float64

# %%
df['region'] = df['region'].replace("SUBURBAN",  0)
df['region'] = df['region'].replace("RURAL",  1)
df['region'] = df['region'].replace("TOWN",  2)
df['region'] = df['region'].replace("INNER_CITY",  3)

# %%
print(df['married'].value_counts(normalize=True) * 100)
# Out:
# married
# YES    66.0
# NO     34.0
# Name: proportion, dtype: float64

# %%
df['married'] = df['married'].replace("YES",  1)
df['married'] = df['married'].replace("NO",  0)

# %%
print(df['children'].value_counts(normalize=True) * 100)
#Colocar peso nos maiores aparecedores
# Out:
# children
# 0    43.833333
# 1    22.500000
# 2    22.333333
# 3    11.333333
# Name: proportion, dtype: float64

# %%
print(df['car'].value_counts(normalize=True) * 100)
# Out:
# car
# NO     50.666667
# YES    49.333333
# Name: proportion, dtype: float64

# %%
df['car'] = df['car'].replace("YES",  0)
df['car'] = df['car'].replace("NO",  1)

# %%
print(df['save_act'].value_counts(normalize=True) * 100)
# Out:
# save_act
# YES    69.0
# NO     31.0
# Name: proportion, dtype: float64

# %%
df['save_act'] = df['save_act'].replace("YES",  1)
df['save_act'] = df['save_act'].replace("NO",  0)

# %%
print(df['current_act'].value_counts(normalize=True) * 100)
# Out:
# current_act
# YES    75.833333
# NO     24.166667
# Name: proportion, dtype: float64

# %%
df['current_act'] = df['current_act'].replace("YES",  1)
df['current_act'] = df['current_act'].replace("NO",  0)

# %%
print(df['mortgage'].value_counts(normalize=True) * 100)
# Out:
# mortgage
# NO     65.166667
# YES    34.833333
# Name: proportion, dtype: float64

# %%
df['mortgage'] = df['mortgage'].replace("YES",  0)
df['mortgage'] = df['mortgage'].replace("NO",  1)

# %%
df.head()
# Out:
#         id  age  sex  region   income  married  children  car  save_act  \
# 0  ID12101   48    0       3  17546.0        0         1    1         0
# 1  ID12102   40    1       2  30085.1        1         3    0         0
# 2  ID12103   51    0       3  16575.4        1         0    0         1
# 3  ID12104   23    0       2  20375.4        1         3    1         0
# 4  ID12105   57    0       1  50576.3        1         0    1         1
#
#    current_act  mortgage  pep
# 0            0         1  YES
# 1            1         0   NO
# 2            1         1   NO
# 3            1         1   NO
# 4            0         1   NO

# %%
df = df.drop(['id'], axis = 1)

# %%
df.head()
# Out:
#    age  sex  region   income  married  children  car  save_act  current_act  \
# 0   48    0       3  17546.0        0         1    1         0            0
# 1   40    1       2  30085.1        1         3    0         0            1
# 2   51    0       3  16575.4        1         0    0         1            1
# 3   23    0       2  20375.4        1         3    1         0            1
# 4   57    0       1  50576.3        1         0    1         1            0
#
#    mortgage  pep
# 0         1  YES
# 1         0   NO
# 2         1   NO
# 3         1   NO
# 4         1   NO

# %%
df.head()
# Out:
#    age  sex  region   income  married  children  car  save_act  current_act  \
# 0   48    0       3  17546.0        0         1    1         0            0
# 1   40    1       2  30085.1        1         3    0         0            1
# 2   51    0       3  16575.4        1         0    0         1            1
# 3   23    0       2  20375.4        1         3    1         0            1
# 4   57    0       1  50576.3        1         0    1         1            0
#
#    mortgage  pep
# 0         1  YES
# 1         0   NO
# 2         1   NO
# 3         1   NO
# 4         1   NO

# %%
df.head()
# Out:
#    age  sex  region   income  married  children  car  save_act  current_act  \
# 0   48    0       3  17546.0        0         1    1         0            0
# 1   40    1       2  30085.1        1         3    0         0            1
# 2   51    0       3  16575.4        1         0    0         1            1
# 3   23    0       2  20375.4        1         3    1         0            1
# 4   57    0       1  50576.3        1         0    1         1            0
#
#    mortgage  pep
# 0         1  YES
# 1         0   NO
# 2         1   NO
# 3         1   NO
# 4         1   NO

# %%
df['income'] = (df['income'].values / 10000).round(2)

# %%
df.head()
# Out:
#    age  sex  region  income  married  children  car  save_act  current_act  \
# 0   48    0       3    1.75        0         1    1         0            0
# 1   40    1       2    3.01        1         3    0         0            1
# 2   51    0       3    1.66        1         0    0         1            1
# 3   23    0       2    2.04        1         3    1         0            1
# 4   57    0       1    5.06        1         0    1         1            0
#
#    mortgage  pep
# 0         1  YES
# 1         0   NO
# 2         1   NO
# 3         1   NO
# 4         1   NO

# %%
X = df.drop('pep', axis = 1)
y = df['pep']

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Calcular a matriz de correlação para as colunas numéricas do DataFrame
corr = df.select_dtypes('number').corr()

# Personalizar a paleta de cores (opcional)
custom_palette = sns.color_palette("RdBu_r", n_colors=50)

# Plotar o mapa de calor usando o Seaborn
plt.figure(figsize=(10, 8))
sns.heatmap(corr, annot=True, cmap=custom_palette, fmt=".2f")
plt.title('Mapa de Calor da Matriz de Correlação')
plt.show()

# %%
df = df.drop(['pep'], axis = 1)
df.head()
# Out:
#    age  sex  region  income  married  children  car  save_act  current_act  \
# 0   48    0       3    1.75        0         1    1         0            0
# 1   40    1       2    3.01        1         3    0         0            1
# 2   51    0       3    1.66        1         0    0         1            1
# 3   23    0       2    2.04        1         3    1         0            1
# 4   57    0       1    5.06        1         0    1         1            0
#
#    mortgage
# 0         1
# 1         0
# 2         1
# 3         1
# 4         1

# %%
import matplotlib.pyplot as plt
df.hist(figsize = (20,15), bins = 20)
plt.show()

# %%
#-----------------------------------KNN INÍCIO---------------------------------------

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=47)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline

modelo = KNeighborsClassifier()

param_grid = {
     'n_neighbors': [3, 5, 7, 9, 11],
    'weights': ['uniform', 'distance'],
    'algorithm': ['auto', 'ball_tree', 'kd_tree', 'brute'],
    'p': [1, 2],  # Para distâncias de Minkowski
    'metric': ['euclidean', 'manhattan']
}

grid_search = GridSearchCV(estimator=modelo, param_grid=param_grid, scoring='accuracy', cv=2, verbose=1)

grid_search.fit(x_train, y_train)

print("Melhores Parâmetros:", grid_search.best_params_)
print("Melhor score de acurácia:", grid_search.best_score_)
# Out:
# Fitting 2 folds for each of 160 candidates, totalling 320 fits
# Melhores Parâmetros: {'algorithm': 'auto', 'metric': 'manhattan', 'n_neighbors': 9, 'p': 1, 'weights': 'distance'}
# Melhor score de acurácia: 0.65625

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline

modelo = Pipeline([
    ('scaler', StandardScaler()),  # Normaliza os dados
    ('knn', KNeighborsClassifier(algorithm = 'auto', metric = 'manhattan', n_neighbors = 9, p = 1, weights = 'distance'))  # Inicia o KNN com K=5
])

modelo = KNeighborsClassifier(algorithm = 'auto', metric = 'manhattan', n_neighbors = 9, p = 1, weights = 'distance')

modelo.fit(x_train, y_train)
# Out:
# KNeighborsClassifier(metric='manhattan', n_neighbors=9, p=1, weights='distance')

# %%
y_pred = modelo.predict(x_test)

resultado = modelo.score(x_test, y_test)
print ("Acurácia:", resultado)
# Out:
# Acurácia: 0.675

# %%
from sklearn.metrics import confusion_matrix, classification_report

y_pred_otimizado = grid_search.best_estimator_.predict(x_test)

conf_matrix = confusion_matrix(y_test, y_pred_otimizado)

print("Matrix de Confusão:")
print(conf_matrix)
# Out:
# Matrix de Confusão:
# [[51 18]
#  [21 30]]

# %%
modelo_otimizado = grid_search.best_estimator_
print("Relatório de Classificação:")
print(classification_report(y_test, y_pred_otimizado))
# Out:
# Relatório de Classificação:
#               precision    recall  f1-score   support
#
#           NO       0.71      0.74      0.72        69
#          YES       0.62      0.59      0.61        51
#
#     accuracy                           0.68       120
#    macro avg       0.67      0.66      0.66       120
# weighted avg       0.67      0.68      0.67       120

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import roc_curve, auc
import matplotlib.pyplot as plt
import numpy as np

y_test_binary = np.pad(y_test_binary, (0, len(y_probs) - len(y_test_binary)), 'constant')

fpr, tpr, thresholds = roc_curve(y_test_binary, y_probs)

roc_auc = auc(fpr, tpr)

plt.figure()
plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic')
plt.legend(loc="lower right")
plt.show()

# %%
#-----------------------------------KNN TÉRMINO---------------------------------------

# %%
#-----------------------------------REGRESSÃO LOGÍSTICA INÍCIO---------------------------------------

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.22, random_state=55)

# %%
from sklearn.linear_model import LogisticRegression
modelo = LogisticRegression()
modelo.fit(x_train , y_train)
# Out:
# LogisticRegression()

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV, train_test_split
from sklearn.linear_model import LogisticRegression

x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.22, random_state=55)

pipeline = Pipeline([
    ('scaler', StandardScaler()),
    ('logreg', LogisticRegression())
])

param_grid = {
    'logreg__penalty': ['l1', 'l2'],
    'logreg__C': [0.001, 0.01, 0.1, 1, 10, 100],
    'logreg__solver': ['liblinear', 'saga'],
    'logreg__max_iter': [100, 1000, 10000],
    'logreg__class_weight': [None, 'balanced'],
    'logreg__random_state': [42]
}

grid_search = GridSearchCV(estimator=pipeline, param_grid=param_grid, scoring='accuracy', cv=2, verbose=1)

grid_search.fit(x_train, y_train)

print("Melhores Parâmetros:", grid_search.best_params_)
print("Melhor score de acurácia:", grid_search.best_score_)

modelo = LogisticRegression(penalty = 'l2', C = 0.01, solver = 'saga', max_iter = 100, class_weight = None, random_state = 42)

modelo.fit(x_train, y_train)

resultado = modelo.score(x_test, y_test)
print("Acurácia:", resultado)
# Out:
# Fitting 2 folds for each of 144 candidates, totalling 288 fits
# Melhores Parâmetros: {'logreg__C': 0.01, 'logreg__class_weight': None, 'logreg__max_iter': 100, 'logreg__penalty': 'l2', 'logreg__random_state': 42, 'logreg__solver': 'saga'}
# Melhor score de acurácia: 0.6217948717948718
# Acurácia: 0.6287878787878788
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import roc_curve, auc
import matplotlib.pyplot as plt

le = LabelEncoder()
le.fit(y_test)
y_test_binary = le.transform(y_test)
y_probs = modelo_otimizado.predict_proba(x_test)[:, 1]
fpr, tpr, thresholds = roc_curve(y_test_binary, y_probs)
roc_auc = auc(fpr, tpr)

plt.figure()
plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (Logistic Regression)')
plt.legend(loc="lower right")
plt.show()

# %%
from sklearn.metrics import confusion_matrix, classification_report

y_pred_otimizado = grid_search.best_estimator_.predict(x_test)

conf_matrix = confusion_matrix(y_test, y_pred_otimizado)

print("Matrix de Confusão:")
print(conf_matrix)
# Out:
# Matrix de Confusão:
# [[54 13]
#  [38 27]]

# %%
modelo_otimizado = grid_search.best_estimator_
print("Relatório de Classificação:")
print(classification_report(y_test, y_pred_otimizado))
# Out:
# Relatório de Classificação:
#               precision    recall  f1-score   support
#
#           NO       0.59      0.81      0.68        67
#          YES       0.68      0.42      0.51        65
#
#     accuracy                           0.61       132
#    macro avg       0.63      0.61      0.60       132
# weighted avg       0.63      0.61      0.60       132

# %%
#-----------------------------------REGRESSÃO LOGÍSTICA TÉRMINO---------------------------------------

# %%
#-----------------------------------ÁRVORE DE DECISÃO INÍCIO---------------------------------------

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.22, random_state=55)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import ExtraTreesClassifier

modelo = ExtraTreesClassifier()

param_grid = {
    'n_estimators': [2, 9, 120],
    'max_depth' : [5, 10, 15],
    'min_samples_leaf' : [2, 3, 4],
    'max_features' : ['sqrt'],
    'class_weight': ['balanced'],
    'random_state': [40, 42, 60]
}

grid_search = GridSearchCV(estimator=modelo, param_grid=param_grid, scoring='accuracy', cv=2, verbose=1)

grid_search.fit(x_train, y_train)

print("Melhores Parâmetros:", grid_search.best_params_)
print("Melhor score de acurácia:", grid_search.best_score_)
# Out:
# Fitting 2 folds for each of 81 candidates, totalling 162 fits
# Melhores Parâmetros: {'class_weight': 'balanced', 'max_depth': 15, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'n_estimators': 120, 'random_state': 60}
# Melhor score de acurácia: 0.8269230769230769

# %%
modelo = ExtraTreesClassifier(n_estimators=120, max_depth=15, min_samples_leaf=2, min_samples_split=2, max_features="sqrt", class_weight="balanced", random_state=60)

modelo.fit(x_train, y_train)
y_pred = modelo.predict(x_test)

# %%
resultado = modelo.score(x_test, y_test)
print ("Acurácia:", resultado)
# Out:
# Acurácia: 0.8712121212121212

# %%
from sklearn.metrics import roc_curve, auc
import matplotlib.pyplot as plt
import numpy as np


le = LabelEncoder()

le.fit(y_test)

y_test_binary = le.transform(y_test)
y_probs = modelo.predict_proba(x_test)[:, 1]
y_test_binary = np.pad(y_test_binary, (0, len(y_probs) - len(y_test_binary)), 'constant')

fpr, tpr, thresholds = roc_curve(y_test_binary, y_probs)

roc_auc = auc(fpr, tpr)

plt.figure()
plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic')
plt.legend(loc="lower right")
plt.show()

# %%
from sklearn.metrics import confusion_matrix, classification_report

y_pred_otimizado = grid_search.best_estimator_.predict(x_test)

conf_matrix = confusion_matrix(y_test, y_pred_otimizado)

print("Matrix de Confusão:")
print(conf_matrix)
# Out:
# Matrix de Confusão:
# [[58  9]
#  [ 8 57]]

# %%
modelo_otimizado = grid_search.best_estimator_
print("Relatório de Classificação:")
print(classification_report(y_test, y_pred_otimizado))
# Out:
# Relatório de Classificação:
#               precision    recall  f1-score   support
#
#           NO       0.88      0.87      0.87        67
#          YES       0.86      0.88      0.87        65
#
#     accuracy                           0.87       132
#    macro avg       0.87      0.87      0.87       132
# weighted avg       0.87      0.87      0.87       132

# %%
#-----------------------------------ÁRVORE DE DECISÃO TÉRMINO---------------------------------------
